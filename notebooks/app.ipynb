# %%
import streamlit as st
import pandas as pd
import joblib
import numpy as np

# Page config
st.set_page_config(
    page_title="Crop Risk & Payout Predictor",
    page_icon="🌾",
    layout="wide",
    initial_sidebar_state="expanded"
)

st.title("🌾 AI-Powered Crop Risk Assessment & Insurance Payout Predictor")
st.markdown("""
An interactive tool for smallholder agricultural insurance.  
Enter season conditions to predict risk level and estimated payout.
""")

# Load saved model and label encoder
@st.cache_resource
def load_model():
    try:
        rf_clf = joblib.load("../models/risk_classifier_rf_v3.joblib")
        le = joblib.load("../models/risk_class_encoder.joblib")
        return rf_clf, le
    except FileNotFoundError as e:
        st.error(f"Model file not found: {e}")
        st.stop()

rf_clf, le = load_model()

# Sidebar inputs
with st.sidebar:
    st.header("Season Parameters")
    
    country = st.selectbox("Country", ["Kenya", "Ethiopia", "Uganda", "Zambia", "Tanzania", "Malawi"])
    crop = st.selectbox("Crop", ["Maize", "Sorghum", "Millet", "Beans", "Cassava", "Groundnut"])
    
    rainfall = st.slider("Seasonal Rainfall (mm)", 40, 2800, 600, step=10)
    temp = st.slider("Avg Temperature (°C)", 15.0, 36.0, 25.0, step=0.5)  # FIXED: all float
    ndvi = st.slider("NDVI Peak", 0.04, 0.96, 0.60, step=0.01)
    soil_ph = st.slider("Soil pH", 4.3, 8.4, 5.9, step=0.1)
    soc = st.slider("Soil Organic Carbon (%)", 0.1, 4.0, 1.0, step=0.1)
    fertilizer = st.slider("Fertilizer N (kg/ha)", 0, 250, 50, step=5)
    pest = st.slider("Pest/Disease Level (0-3)", 0, 3, 1)
    irrigated = st.checkbox("Irrigated?", value=False)
    
# Prediction button
if st.sidebar.button("Generate Prediction", type="primary", use_container_width=True):
    # Build input DataFrame
    input_dict = {
        'rainfall_mm': rainfall,
        'avg_temp_c': temp,
        'heat_stress_days': max(0, int((temp - 28) * 4)),
        'ndvi_peak': ndvi,
        'soil_ph': soil_ph,
        'soc_percent': soc,
        'fertilizer_n_kg_ha': fertilizer,
        'pest_disease_level': pest,
        'irrigated': 1 if irrigated else 0
    }

    input_df = pd.DataFrame([input_dict])

    # One-hot encode country & crop (must match training columns)
    for c in ["Kenya", "Malawi", "Tanzania", "Uganda", "Zambia"]:
        input_df[f'country_{c}'] = 1 if country == c else 0

    for cr in ["Cassava", "Groundnut", "Maize", "Millet", "Sorghum"]:
        input_df[f'crop_{cr}'] = 1 if crop == cr else 0

    # Fill missing columns with 0 (safe-guard)
    # Replace with your actual training feature names if needed
    expected_cols = [
        'rainfall_mm', 'avg_temp_c', 'heat_stress_days', 'ndvi_peak', 'soil_ph',
        'soc_percent', 'fertilizer_n_kg_ha', 'pest_disease_level', 'irrigated',
        'country_Kenya', 'country_Malawi', 'country_Tanzania', 'country_Uganda', 'country_Zambia',
        'crop_Cassava', 'crop_Groundnut', 'crop_Maize', 'crop_Millet', 'crop_Sorghum'
        # Add any other engineered columns you used, e.g. 'drought_index' if present
    ]

    for col in expected_cols:
        if col not in input_df.columns:
            input_df[col] = 0

    input_df = input_df[expected_cols]

    # Predict
    risk_encoded = rf_clf.predict(input_df)[0]
    risk_level = le.inverse_transform([risk_encoded])[0]

    # Approximate payout based on risk level
    if risk_level == 'Low':
        payout_est = 50
        payout_range = "$0 – $100 (minimal/no payout)"
    elif risk_level == 'Medium':
        payout_est = 250
        payout_range = "$150 – $350 (partial loss)"
    else:  # High
        payout_est = 500
        payout_range = "$400 – $600 (severe loss)"

    # Display results
    st.subheader("Prediction Results")
    col1, col2, col3 = st.columns(3)

    col1.metric("Predicted Risk Level", risk_level, delta_color="normal" if risk_level == "Low" else "inverse" if risk_level == "High" else None)
    col2.metric("Estimated Payout (USD/ha)", f"${payout_est}", delta_color="normal")
    col3.metric("Payout Range", payout_range)

    st.success(f"Model accuracy: 89.7% overall | Medium class recall: 71.7%")

    st.info("Payout is approximated from predicted risk class (based on strong classification model). For more precise payouts, regression models can be explored in future iterations.")
# Out:
# 2026-02-09 15:18:46.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:48.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:48.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:50.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:50.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:52.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:52.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:52.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:53.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:53.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:53.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:53.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:53.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:54.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:54.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:57.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:58.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:18:59.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:00.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:01.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 15:19:01.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
